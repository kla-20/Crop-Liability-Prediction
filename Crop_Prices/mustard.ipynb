# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading
# ## Mustard Data set!

# %%
df = pd.read_csv('/content/drive/MyDrive/crops_dataset/mustard.csv')

# %%
df
# Out:
#         District Name  Market Name Commodity   Variety    Grade  \
# 0            Kurnool        Adoni   Mustard     Other      FAQ
# 1            Kurnool         Alur   Mustard     Other   Medium
# 2            Kurnool         Alur   Mustard   Mustard   Medium
# 3            Kurnool         Alur   Mustard     Other   Medium
# 4            Kurnool         Alur   Mustard   Mustard   Medium
# ...               ...          ...       ...       ...      ...
# 1014643   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014644   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014645   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014646   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014647   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
#
#          Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0                         1550.0                   1600.0
# 1                         2918.0                   2918.0
# 2                         3018.0                   3018.0
# 3                         3018.0                   3018.0
# 4                         2598.0                   2598.0
# ...                          ...                      ...
# 1014643                   4300.0                   4500.0
# 1014644                   4300.0                   4500.0
# 1014645                   4300.0                   4500.0
# 1014646                   4300.0                   4500.0
# 1014647                   4300.0                   4500.0
#
#          Modal Price (Rs./Quintal)  Price Date           State
# 0                           1575.0  20-02-2009  Andhra Pradesh
# 1                           2918.0  03-05-2013  Andhra Pradesh
# 2                           3018.0  25-03-2013  Andhra Pradesh
# 3                           3018.0  25-03-2013  Andhra Pradesh
# 4                           2598.0  22-04-2012  Andhra Pradesh
# ...                            ...         ...             ...
# 1014643                     4400.0  05-06-2016     West Bengal
# 1014644                     4400.0  04-06-2016     West Bengal
# 1014645                     4400.0  03-06-2016     West Bengal
# 1014646                     4400.0  02-06-2016     West Bengal
# 1014647                     4400.0  01-06-2016     West Bengal
#
# [1014648 rows x 10 columns]

# %% [markdown]
# # Pre-processing

# %%
df.shape
# Out:
# (1014648, 10)

# %%
rows = df.shape[0]
rows
# Out:
# 1014648

# %%
cols = df.shape[1]
cols
# Out:
# 10

# %%
df.isna().any()
# Out:
# District Name                False
# Market Name                  False
# Commodity                    False
# Variety                      False
# Grade                        False
# Min Price (Rs./Quintal)      False
# Max Price (Rs./Quintal)      False
# Modal Price (Rs./Quintal)    False
# Price Date                   False
# State                        False
# dtype: bool

# %% [markdown]
# ## Dealing with Null Values!

# %%
# Number of Null values in the entire dataframe
df.isna().sum().sum()
# Out:
# 0

# %%
## Checking number of null values in all the columns!

column_names = list(df.columns)
for i in range(0, len(column_names)):
  print(f"Column No: {i+1} = {column_names[i]} has {df[column_names[i]].isna().sum()} Null values!")
# Out:
# Column No: 1 = District Name has 0 Null values!
# Column No: 2 = Market Name has 0 Null values!
# Column No: 3 = Commodity has 0 Null values!
# Column No: 4 = Variety has 0 Null values!
# Column No: 5 = Grade has 0 Null values!
# Column No: 6 = Min Price (Rs./Quintal) has 0 Null values!
# Column No: 7 = Max Price (Rs./Quintal) has 0 Null values!
# Column No: 8 = Modal Price (Rs./Quintal) has 0 Null values!
# Column No: 9 = Price Date has 0 Null values!
# Column No: 10 = State has 0 Null values!

# %%
# No of unique values in all the columns

for i in range(0, len(column_names)):
  print(f'The column {column_names[i]} has {df[column_names[i]].nunique()} unique values!')
# Out:
# The column District Name has 332 unique values!
# The column Market Name has 1086 unique values!
# The column Commodity has 1 unique values!
# The column Variety has 11 unique values!
# The column Grade has 3 unique values!
# The column Min Price (Rs./Quintal) has 6759 unique values!
# The column Max Price (Rs./Quintal) has 7539 unique values!
# The column Modal Price (Rs./Quintal) has 7821 unique values!
# The column Price Date has 5113 unique values!
# The column State has 26 unique values!

# %%
df.columns
# Out:
# Index(['District Name', 'Market Name', 'Commodity', 'Variety', 'Grade',
#        'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal Price (Rs./Quintal)', 'Price Date', 'State'],
#       dtype='object')

# %%
import pandas as pd

# Assuming df is your DataFrame
df.columns = df.columns.str.replace(' ', '_').str.lower()

# Alternatively, you can use the following code to replace spaces with underscores and convert to lowercase
# df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# Now, the column names will be in lowercase and with underscores instead of spaces
print(df.columns)
# Out:
# Index(['district_name', 'market_name', 'commodity', 'variety', 'grade',
#        'min_price_(rs./quintal)', 'max_price_(rs./quintal)',
#        'modal_price_(rs./quintal)', 'price_date', 'state'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   district_name market_name commodity   variety    grade  \
# 0      Kurnool       Adoni   Mustard     Other      FAQ
# 1      Kurnool        Alur   Mustard     Other   Medium
# 2      Kurnool        Alur   Mustard   Mustard   Medium
# 3      Kurnool        Alur   Mustard     Other   Medium
# 4      Kurnool        Alur   Mustard   Mustard   Medium
#
#    min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                   1550.0                   1600.0
# 1                   2918.0                   2918.0
# 2                   3018.0                   3018.0
# 3                   3018.0                   3018.0
# 4                   2598.0                   2598.0
#
#    modal_price_(rs./quintal)  price_date           state
# 0                     1575.0  20-02-2009  Andhra Pradesh
# 1                     2918.0  03-05-2013  Andhra Pradesh
# 2                     3018.0  25-03-2013  Andhra Pradesh
# 3                     3018.0  25-03-2013  Andhra Pradesh
# 4                     2598.0  22-04-2012  Andhra Pradesh

# %%
df['month'] = df['price_date'].str[3:5].astype(int)
df['year'] = df['price_date'].str[6:].astype(int)

# %%
df.head(3)
# Out:
#   district_name market_name commodity   variety    grade  \
# 0      Kurnool       Adoni   Mustard     Other      FAQ
# 1      Kurnool        Alur   Mustard     Other   Medium
# 2      Kurnool        Alur   Mustard   Mustard   Medium
#
#    min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                   1550.0                   1600.0
# 1                   2918.0                   2918.0
# 2                   3018.0                   3018.0
#
#    modal_price_(rs./quintal)  price_date           state  month  year
# 0                     1575.0  20-02-2009  Andhra Pradesh      2  2009
# 1                     2918.0  03-05-2013  Andhra Pradesh      5  2013
# 2                     3018.0  25-03-2013  Andhra Pradesh      3  2013

# %%
df['price_date'].dtype
# Out:
# dtype('O')

# %%
# Convert 'price_date' to timestamp
df['price_date'] = pd.to_datetime(df['price_date'], format='%d-%m-%Y')

# Convert 'month' and 'year' to int
df['month'] = df['month'].astype(int)
df['year'] = df['year'].astype(int)

# Display the updated DataFrame
print(df.dtypes)
# Out:
# district_name                        object
# market_name                          object
# commodity                            object
# variety                              object
# grade                                object
# min_price_(rs./quintal)             float64
# max_price_(rs./quintal)             float64
# modal_price_(rs./quintal)           float64
# price_date                   datetime64[ns]
# state                                object
# month                                 int64
# year                                  int64
# dtype: object

# %%
df_copy = df

# %% [markdown]
# # Encoding Columns

# %% [markdown]
# ## district Name

# %%
df['district_name'].nunique()
# Out:
# 332

# %%
value_counts = df['district_name'].value_counts()

# %%
value_counts
# Out:
# Ganganagar         35492
# Banaskanth         22522
# Bharatpur          18705
# Burdwan            18092
# Agra               17958
#                    ...
# Nowarangpur            1
# Udupi                  1
# Tumkur                 1
# Alleppey               1
# Uttar Dinajpur         1
# Name: district_name, Length: 332, dtype: int64

# %%
district_name_frequency = df['district_name'].value_counts(normalize=False)

# Create a new column with encoded values
df['district_name_encoded'] = df['district_name'].map(district_name_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name commodity   variety    grade  \
# 0      Kurnool       Adoni   Mustard     Other      FAQ
# 1      Kurnool        Alur   Mustard     Other   Medium
# 2      Kurnool        Alur   Mustard   Mustard   Medium
# 3      Kurnool        Alur   Mustard     Other   Medium
# 4      Kurnool        Alur   Mustard   Mustard   Medium
#
#    min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                   1550.0                   1600.0
# 1                   2918.0                   2918.0
# 2                   3018.0                   3018.0
# 3                   3018.0                   3018.0
# 4                   2598.0                   2598.0
#
#    modal_price_(rs./quintal) price_date           state  month  year  \
# 0                     1575.0 2009-02-20  Andhra Pradesh      2  2009
# 1                     2918.0 2013-05-03  Andhra Pradesh      5  2013
# 2                     3018.0 2013-03-25  Andhra Pradesh      3  2013
# 3                     3018.0 2013-03-25  Andhra Pradesh      3  2013
# 4                     2598.0 2012-04-22  Andhra Pradesh      4  2012
#
#    district_name_encoded
# 0                      9
# 1                      9
# 2                      9
# 3                      9
# 4                      9

# %% [markdown]
# ## market name

# %%
df['market_name'].nunique()
# Out:
# 1086

# %%
value_counts = df['market_name'].value_counts()

# %%
value_counts
# Out:
# Samsi                         6258
# Pratapgarh                    5007
# Bishnupur(Bankura)            4786
# Unjha                         4579
# Fatehpur                      4556
#                               ...
# Jalna(Badnapur)                  1
# Dhanera(Veg,Yard Dhanera)        1
# Digras                           1
# Barshi(Vairag)                   1
# Adoni                            1
# Name: market_name, Length: 1086, dtype: int64

# %%
market_name_frequency = df['market_name'].value_counts(normalize=False)

# Create a new column with encoded values
df['market_name_encoded'] = df['market_name'].map(market_name_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name commodity   variety    grade  \
# 0      Kurnool       Adoni   Mustard     Other      FAQ
# 1      Kurnool        Alur   Mustard     Other   Medium
# 2      Kurnool        Alur   Mustard   Mustard   Medium
# 3      Kurnool        Alur   Mustard     Other   Medium
# 4      Kurnool        Alur   Mustard   Mustard   Medium
#
#    min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                   1550.0                   1600.0
# 1                   2918.0                   2918.0
# 2                   3018.0                   3018.0
# 3                   3018.0                   3018.0
# 4                   2598.0                   2598.0
#
#    modal_price_(rs./quintal) price_date           state  month  year  \
# 0                     1575.0 2009-02-20  Andhra Pradesh      2  2009
# 1                     2918.0 2013-05-03  Andhra Pradesh      5  2013
# 2                     3018.0 2013-03-25  Andhra Pradesh      3  2013
# 3                     3018.0 2013-03-25  Andhra Pradesh      3  2013
# 4                     2598.0 2012-04-22  Andhra Pradesh      4  2012
#
#    district_name_encoded  market_name_encoded
# 0                      9                    1
# 1                      9                    6
# 2                      9                    6
# 3                      9                    6
# 4                      9                    6

# %%
df = df.drop('commodity',axis=1)

# %% [markdown]
# ## variety

# %%
df['variety'].nunique()
# Out:
# 11

# %%
value_counts = df['variety'].value_counts()

# %%
variety_frequency = df['variety'].value_counts(normalize=False)

# Create a new column with encoded values
df['variety_encoded'] = df['variety'].map(variety_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name   variety    grade  min_price_(rs./quintal)  \
# 0      Kurnool       Adoni     Other      FAQ                    1550.0
# 1      Kurnool        Alur     Other   Medium                    2918.0
# 2      Kurnool        Alur   Mustard   Medium                    3018.0
# 3      Kurnool        Alur     Other   Medium                    3018.0
# 4      Kurnool        Alur   Mustard   Medium                    2598.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal) price_date  \
# 0                   1600.0                     1575.0 2009-02-20
# 1                   2918.0                     2918.0 2013-05-03
# 2                   3018.0                     3018.0 2013-03-25
# 3                   3018.0                     3018.0 2013-03-25
# 4                   2598.0                     2598.0 2012-04-22
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh      2  2009                      9                    1
# 1  Andhra Pradesh      5  2013                      9                    6
# 2  Andhra Pradesh      3  2013                      9                    6
# 3  Andhra Pradesh      3  2013                      9                    6
# 4  Andhra Pradesh      4  2012                      9                    6
#
#    variety_encoded
# 0           544052
# 1           544052
# 2           109340
# 3           544052
# 4           109340

# %% [markdown]
# ## grade

# %%
df['grade'].unique()
# Out:
# array(['FAQ ', 'Medium ', 'Large '], dtype=object)

# %%
value_counts = df['grade'].value_counts()
value_counts
# Out:
# FAQ        1014387
# Medium         248
# Large           13
# Name: grade, dtype: int64

# %%
grade_frequency = df['grade'].value_counts(normalize=False)

# Create a new column with encoded values
df['grade_encoded'] = df['grade'].map(grade_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name   variety    grade  min_price_(rs./quintal)  \
# 0      Kurnool       Adoni     Other      FAQ                    1550.0
# 1      Kurnool        Alur     Other   Medium                    2918.0
# 2      Kurnool        Alur   Mustard   Medium                    3018.0
# 3      Kurnool        Alur     Other   Medium                    3018.0
# 4      Kurnool        Alur   Mustard   Medium                    2598.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal) price_date  \
# 0                   1600.0                     1575.0 2009-02-20
# 1                   2918.0                     2918.0 2013-05-03
# 2                   3018.0                     3018.0 2013-03-25
# 3                   3018.0                     3018.0 2013-03-25
# 4                   2598.0                     2598.0 2012-04-22
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh      2  2009                      9                    1
# 1  Andhra Pradesh      5  2013                      9                    6
# 2  Andhra Pradesh      3  2013                      9                    6
# 3  Andhra Pradesh      3  2013                      9                    6
# 4  Andhra Pradesh      4  2012                      9                    6
#
#    variety_encoded  grade_encoded
# 0           544052        1014387
# 1           544052            248
# 2           109340            248
# 3           544052            248
# 4           109340            248

# %% [markdown]
# ## state

# %%
df['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'NCT of Delhi', 'Gujarat', 'Himachal Pradesh', 'Haryana',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Meghalaya', 'Maharashtra',
#        'Manipur', 'Madhya Pradesh', 'Mizoram', 'Odisha', 'Punjab',
#        'Pondicherry', 'Rajasthan', 'Telangana', 'Tamil Nadu', 'Tripura',
#        'Uttrakhand', 'Uttar Pradesh', 'West Bengal'], dtype=object)

# %%
value_counts = df['state'].value_counts()
value_counts
# Out:
# Uttar Pradesh        352554
# Rajasthan            255782
# Madhya Pradesh       207727
# Gujarat               79155
# West Bengal           64997
# Haryana               23665
# Maharashtra            7846
# Assam                  5734
# NCT of Delhi           5272
# Jharkhand              3706
# Karnataka              3484
# Punjab                 1115
# Manipur                 690
# Uttrakhand              593
# Kerala                  552
# Telangana               475
# Bihar                   462
# Mizoram                 414
# Odisha                  176
# Pondicherry             106
# Meghalaya                50
# Himachal Pradesh         31
# Tamil Nadu               28
# Andhra Pradesh           21
# Arunachal Pradesh        11
# Tripura                   2
# Name: state, dtype: int64

# %%
state_frequency = df['state'].value_counts(normalize=False)

# Create a new column with encoded values
df['state_encoded'] = df['state'].map(state_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name   variety    grade  min_price_(rs./quintal)  \
# 0      Kurnool       Adoni     Other      FAQ                    1550.0
# 1      Kurnool        Alur     Other   Medium                    2918.0
# 2      Kurnool        Alur   Mustard   Medium                    3018.0
# 3      Kurnool        Alur     Other   Medium                    3018.0
# 4      Kurnool        Alur   Mustard   Medium                    2598.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal) price_date  \
# 0                   1600.0                     1575.0 2009-02-20
# 1                   2918.0                     2918.0 2013-05-03
# 2                   3018.0                     3018.0 2013-03-25
# 3                   3018.0                     3018.0 2013-03-25
# 4                   2598.0                     2598.0 2012-04-22
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh      2  2009                      9                    1
# 1  Andhra Pradesh      5  2013                      9                    6
# 2  Andhra Pradesh      3  2013                      9                    6
# 3  Andhra Pradesh      3  2013                      9                    6
# 4  Andhra Pradesh      4  2012                      9                    6
#
#    variety_encoded  grade_encoded  state_encoded
# 0           544052        1014387             21
# 1           544052            248             21
# 2           109340            248             21
# 3           544052            248             21
# 4           109340            248             21

# %% [markdown]
# # Taking only the Encoded columns

# %%
df_encoded = df[['district_name_encoded', 'market_name_encoded', 'variety_encoded', 'grade_encoded', 'state_encoded', 'month', 'year', 'price_date', 'min_price_(rs./quintal)', 'max_price_(rs./quintal)', 'modal_price_(rs./quintal)']]

# %% [markdown]
# # Encoded Dataset

# %%
df_encoded.head(8)
# Out:
#    district_name_encoded  market_name_encoded  variety_encoded  grade_encoded  \
# 0                      9                    1           544052        1014387
# 1                      9                    6           544052            248
# 2                      9                    6           109340            248
# 3                      9                    6           544052            248
# 4                      9                    6           109340            248
# 5                      9                    6           544052            248
# 6                      9                    6           544052            248
# 7                      9                    9           544052        1014387
#
#    state_encoded  month  year price_date  min_price_(rs./quintal)  \
# 0             21      2  2009 2009-02-20                   1550.0
# 1             21      5  2013 2013-05-03                   2918.0
# 2             21      3  2013 2013-03-25                   3018.0
# 3             21      3  2013 2013-03-25                   3018.0
# 4             21      4  2012 2012-04-22                   2598.0
# 5             21      3  2012 2012-03-13                   2557.0
# 6             21      3  2012 2012-03-09                   2555.0
# 7             21      5  2014 2014-05-10                   3200.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal)
# 0                   1600.0                     1575.0
# 1                   2918.0                     2918.0
# 2                   3018.0                     3018.0
# 3                   3018.0                     3018.0
# 4                   2598.0                     2598.0
# 5                   2557.0                     2557.0
# 6                   2555.0                     2555.0
# 7                   3300.0                     3250.0

# %% [markdown]
# # Heat Map

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_encoded is your DataFrame
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(df_encoded.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-46-f636cb7d937b>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df_encoded.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# %% [markdown]
# # Models and Evaluation

# %%
# Evaluation Metrics

def Emetrics(y_test,y_pred):
  from sklearn import metrics

  # Print result of MAE
  print(f"Mean Absoulute error is : {metrics.mean_absolute_error(y_test,y_pred)}")

  # Print result of RMSE
  print(f"Root Mean Square error is: {np.sqrt(metrics.mean_squared_error(y_test,y_pred))}")

  # Print result of R2
  print(f"R2 score is: {metrics.r2_score(y_test,y_pred)}")

# %%
df_encoded.head(5)
# Out:
#    district_name_encoded  market_name_encoded  variety_encoded  grade_encoded  \
# 0                      9                    1           544052        1014387
# 1                      9                    6           544052            248
# 2                      9                    6           109340            248
# 3                      9                    6           544052            248
# 4                      9                    6           109340            248
#
#    state_encoded  month  year price_date  min_price_(rs./quintal)  \
# 0             21      2  2009 2009-02-20                   1550.0
# 1             21      5  2013 2013-05-03                   2918.0
# 2             21      3  2013 2013-03-25                   3018.0
# 3             21      3  2013 2013-03-25                   3018.0
# 4             21      4  2012 2012-04-22                   2598.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal)
# 0                   1600.0                     1575.0
# 1                   2918.0                     2918.0
# 2                   3018.0                     3018.0
# 3                   3018.0                     3018.0
# 4                   2598.0                     2598.0

# %% [markdown]
# # Outlier Removing rows

# %%
import pandas as pd
from scipy.stats import zscore

# Assuming df_encoded is your DataFrame
# Replace 'df_encoded' with your actual DataFrame name

# Function to identify outliers using Z-score
def identify_outliers_zscore(df, threshold=3):
    z_scores = zscore(df.select_dtypes(include=['float64', 'int64']))
    outliers = (abs(z_scores) > threshold).any(axis=1)
    return outliers

# Identify outliers
outliers = identify_outliers_zscore(df_encoded)

# Remove rows with outliers
df_cleaned = df_encoded[~outliers]

# %%
df_encoded = df_cleaned

# %% [markdown]
# ## Standardizing values (min-max scalar)

# %%
df_encoded
# Out:
#          district_name_encoded  market_name_encoded  variety_encoded  \
# 0                            9                    1           544052
# 7                            9                    9           544052
# 8                            9                    9           544052
# 9                            9                    9           544052
# 10                           9                    9           544052
# ...                        ...                  ...              ...
# 1014643                   2432                 1231           109340
# 1014644                   2432                 1231           109340
# 1014645                   2432                 1231           109340
# 1014646                   2432                 1231           109340
# 1014647                   2432                 1231           109340
#
#          grade_encoded  state_encoded  month  year price_date  \
# 0              1014387             21      2  2009 2009-02-20
# 7              1014387             21      5  2014 2014-05-10
# 8              1014387             21      3  2014 2014-03-15
# 9              1014387             21      3  2014 2014-03-11
# 10             1014387             21      3  2014 2014-03-05
# ...                ...            ...    ...   ...        ...
# 1014643        1014387          64997      6  2016 2016-06-05
# 1014644        1014387          64997      6  2016 2016-06-04
# 1014645        1014387          64997      6  2016 2016-06-03
# 1014646        1014387          64997      6  2016 2016-06-02
# 1014647        1014387          64997      6  2016 2016-06-01
#
#          min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                         1550.0                   1600.0
# 7                         3200.0                   3300.0
# 8                         2712.0                   2725.0
# 9                         2728.0                   2850.0
# 10                        2850.0                   2875.0
# ...                          ...                      ...
# 1014643                   4300.0                   4500.0
# 1014644                   4300.0                   4500.0
# 1014645                   4300.0                   4500.0
# 1014646                   4300.0                   4500.0
# 1014647                   4300.0                   4500.0
#
#          modal_price_(rs./quintal)
# 0                           1575.0
# 7                           3250.0
# 8                           2718.0
# 9                           2789.0
# 10                          2863.0
# ...                            ...
# 1014643                     4400.0
# 1014644                     4400.0
# 1014645                     4400.0
# 1014646                     4400.0
# 1014647                     4400.0
#
# [951644 rows x 11 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df_encoded is your DataFrame
# Replace 'df_encoded' with your actual DataFrame name

# Columns to be scaled
columns_to_scale = ['district_name_encoded', 'market_name_encoded', 'variety_encoded', 'grade_encoded', 'state_encoded']

# Min-Max Scaling
min_max_scaler = MinMaxScaler()
df_encoded[columns_to_scale] = min_max_scaler.fit_transform(df_encoded[columns_to_scale])

# %%
df_encoded.head(5)
# Out:
#     district_name_encoded  market_name_encoded  variety_encoded  \
# 0                0.000355             0.000000              1.0
# 7                0.000355             0.001598              1.0
# 8                0.000355             0.001598              1.0
# 9                0.000355             0.001598              1.0
# 10               0.000355             0.001598              1.0
#
#     grade_encoded  state_encoded  month  year price_date  \
# 0             0.0       0.000054      2  2009 2009-02-20
# 7             0.0       0.000054      5  2014 2014-05-10
# 8             0.0       0.000054      3  2014 2014-03-15
# 9             0.0       0.000054      3  2014 2014-03-11
# 10            0.0       0.000054      3  2014 2014-03-05
#
#     min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                    1550.0                   1600.0
# 7                    3200.0                   3300.0
# 8                    2712.0                   2725.0
# 9                    2728.0                   2850.0
# 10                   2850.0                   2875.0
#
#     modal_price_(rs./quintal)
# 0                      1575.0
# 7                      3250.0
# 8                      2718.0
# 9                      2789.0
# 10                     2863.0

# %% [markdown]
# ## Forward Stepwise Selection

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

def forward_stepwise_selection(X, y):
    # Initialize an empty set of features
    selected_features = []

    # Initialize a linear regression model
    model = LinearRegression()

    # Loop until all features have been added to the model
    while len(selected_features) < X.shape[1]:

        # Initialize variables to keep track of best feature and score
        best_feature = None
        best_score = -np.inf

        # Loop over all remaining features
        for feature in X.columns:
            if feature not in selected_features:
                # Fit a model with the current set of features plus the new feature
                current_features = selected_features + [feature]
                X_current = X[current_features]
                model.fit(X_current, y)

                # Calculate the score for the new model
                y_pred = model.predict(X_current)
                score = r2_score(y, y_pred)

                # Keep track of the best feature and score
                if score > best_score:
                    best_feature = feature
                    best_score = score

        # Add the best feature to the selected features and print the result
        selected_features.append(best_feature)
        print(f'Selected feature: {best_feature}, Score: {best_score:.4f}')

    return selected_features

# %%
X = df_encoded.loc[:, ['district_name_encoded',	'market_name_encoded',	'variety_encoded',	'grade_encoded',	'state_encoded',	'month',	'year']]
y = df_encoded.loc[:, ['min_price_(rs./quintal)',	'max_price_(rs./quintal)',	'modal_price_(rs./quintal)']]

# %%
print(forward_stepwise_selection(X, y))
# Out:
# Selected feature: year, Score: 0.4664
# Selected feature: state_encoded, Score: 0.5020
# Selected feature: month, Score: 0.5111
# Selected feature: district_name_encoded, Score: 0.5128
# Selected feature: market_name_encoded, Score: 0.5138
# Selected feature: variety_encoded, Score: 0.5142
# Selected feature: grade_encoded, Score: 0.5142
# ['year', 'state_encoded', 'month', 'district_name_encoded', 'market_name_encoded', 'variety_encoded', 'grade_encoded']

# %% [markdown]
# ### All the features are closely important

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .4, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lnregressor = LinearRegression()
lnregressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lnregressor.predict(X_test)
y_pred
# Out:
# array([[4190.1382068 , 4483.86492836, 4421.83537047],
#        [3658.89333582, 3857.15669394, 4181.72694876],
#        [4309.36913494, 4548.06417549, 4499.98213734],
#        ...,
#        [1656.64882955, 1732.54375615, 2252.74179464],
#        [1840.5384277 , 1997.79341082, 2449.07459971],
#        [1657.72370405, 1785.97843262, 2452.32391763]])

# %%
# Evaluation metrics for Linear Regression
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 673.9414588016866
# Root Mean Square error is: 941.194779349621
# R2 score is: 0.5148324590138049

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

dt_regressor = DecisionTreeRegressor(random_state=42)

# Train the model using the training sets
dt_regressor.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = dt_regressor.predict(X_test)

# %%
# Evaluation metrics for Linear Regression
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 110.83483902287087
# Root Mean Square error is: 271.60438913416414
# R2 score is: 0.9579067896113065

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(
    n_estimators=200,  # Reduced number of trees
    max_depth=30,  # Reduced maximum depth
    random_state=42,
    bootstrap=True,
    warm_start=True,  # Enable incremental training
    n_jobs=-1  # Utilize all CPU cores
)

# Train the model
rf_regressor.fit(X_train, y_train)

# Make predictions
y_pred = rf_regressor.predict(X_test)

# %%
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 110.10237198789294
# Root Mean Square error is: 264.267960676287
# R2 score is: 0.96018863898288

# %% [markdown]
# ## XgBoost Regression

# %%
from xgboost import XGBRegressor
# Create the XGBoost regression model
xg_regressor = XGBRegressor(n_estimators=250, learning_rate=0.37,random_state=42)

# Train the model
xg_regressor.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = xg_regressor.predict(X_test)

# Evaluate the model's performance
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 183.74180386024878
# Root Mean Square error is: 334.051395473865
# R2 score is: 0.9383478562126308

# %% [markdown]
# ## KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# Create the KNN regression model
knn_regressor = KNeighborsRegressor(n_neighbors=5)  # You can adjust the number of neighbors as needed

# Train the model
knn_regressor.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = knn_regressor.predict(X_test)


# Evaluate the model's performance
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 126.40658522348009
# Root Mean Square error is: 308.33359382776524
# R2 score is: 0.946494867960893

# %% [markdown]
# # Datasets of Mustard

# %% [markdown]
# ## Main

# %%
df
# Out:
#         district_name  market_name   variety    grade  \
# 0            Kurnool        Adoni     Other      FAQ
# 1            Kurnool         Alur     Other   Medium
# 2            Kurnool         Alur   Mustard   Medium
# 3            Kurnool         Alur     Other   Medium
# 4            Kurnool         Alur   Mustard   Medium
# ...               ...          ...       ...      ...
# 1014643   Coochbehar   Toofanganj   Mustard      FAQ
# 1014644   Coochbehar   Toofanganj   Mustard      FAQ
# 1014645   Coochbehar   Toofanganj   Mustard      FAQ
# 1014646   Coochbehar   Toofanganj   Mustard      FAQ
# 1014647   Coochbehar   Toofanganj   Mustard      FAQ
#
#          min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                         1550.0                   1600.0
# 1                         2918.0                   2918.0
# 2                         3018.0                   3018.0
# 3                         3018.0                   3018.0
# 4                         2598.0                   2598.0
# ...                          ...                      ...
# 1014643                   4300.0                   4500.0
# 1014644                   4300.0                   4500.0
# 1014645                   4300.0                   4500.0
# 1014646                   4300.0                   4500.0
# 1014647                   4300.0                   4500.0
#
#          modal_price_(rs./quintal) price_date           state  month  year  \
# 0                           1575.0 2009-02-20  Andhra Pradesh      2  2009
# 1                           2918.0 2013-05-03  Andhra Pradesh      5  2013
# 2                           3018.0 2013-03-25  Andhra Pradesh      3  2013
# 3                           3018.0 2013-03-25  Andhra Pradesh      3  2013
# 4                           2598.0 2012-04-22  Andhra Pradesh      4  2012
# ...                            ...        ...             ...    ...   ...
# 1014643                     4400.0 2016-06-05     West Bengal      6  2016
# 1014644                     4400.0 2016-06-04     West Bengal      6  2016
# 1014645                     4400.0 2016-06-03     West Bengal      6  2016
# 1014646                     4400.0 2016-06-02     West Bengal      6  2016
# 1014647                     4400.0 2016-06-01     West Bengal      6  2016
#
#          district_name_encoded  market_name_encoded  variety_encoded  \
# 0                            9                    1           544052
# 1                            9                    6           544052
# 2                            9                    6           109340
# 3                            9                    6           544052
# 4                            9                    6           109340
# ...                        ...                  ...              ...
# 1014643                   2432                 1231           109340
# 1014644                   2432                 1231           109340
# 1014645                   2432                 1231           109340
# 1014646                   2432                 1231           109340
# 1014647                   2432                 1231           109340
#
#          grade_encoded  state_encoded
# 0              1014387             21
# 1                  248             21
# 2                  248             21
# 3                  248             21
# 4                  248             21
# ...                ...            ...
# 1014643        1014387          64997
# 1014644        1014387          64997
# 1014645        1014387          64997
# 1014646        1014387          64997
# 1014647        1014387          64997
#
# [1014648 rows x 16 columns]

# %% [markdown]
# ### Saving the dataframe of mustard
#
# > Indented block

# %%
df.to_csv('musdf.csv')

# %% [markdown]
# ## Encoded

# %%
df_encoded
# Out:
#          district_name_encoded  market_name_encoded  variety_encoded  \
# 0                     0.000355             0.000000         1.000000
# 7                     0.000355             0.001598         1.000000
# 8                     0.000355             0.001598         1.000000
# 9                     0.000355             0.001598         1.000000
# 10                    0.000355             0.001598         1.000000
# ...                        ...                  ...              ...
# 1014643               0.107944             0.245705         0.200972
# 1014644               0.107944             0.245705         0.200972
# 1014645               0.107944             0.245705         0.200972
# 1014646               0.107944             0.245705         0.200972
# 1014647               0.107944             0.245705         0.200972
#
#          grade_encoded  state_encoded  month  year price_date  \
# 0                  0.0       0.000054      2  2009 2009-02-20
# 7                  0.0       0.000054      5  2014 2014-05-10
# 8                  0.0       0.000054      3  2014 2014-03-15
# 9                  0.0       0.000054      3  2014 2014-03-11
# 10                 0.0       0.000054      3  2014 2014-03-05
# ...                ...            ...    ...   ...        ...
# 1014643            0.0       0.184356      6  2016 2016-06-05
# 1014644            0.0       0.184356      6  2016 2016-06-04
# 1014645            0.0       0.184356      6  2016 2016-06-03
# 1014646            0.0       0.184356      6  2016 2016-06-02
# 1014647            0.0       0.184356      6  2016 2016-06-01
#
#          min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 0                         1550.0                   1600.0
# 7                         3200.0                   3300.0
# 8                         2712.0                   2725.0
# 9                         2728.0                   2850.0
# 10                        2850.0                   2875.0
# ...                          ...                      ...
# 1014643                   4300.0                   4500.0
# 1014644                   4300.0                   4500.0
# 1014645                   4300.0                   4500.0
# 1014646                   4300.0                   4500.0
# 1014647                   4300.0                   4500.0
#
#          modal_price_(rs./quintal)
# 0                           1575.0
# 7                           3250.0
# 8                           2718.0
# 9                           2789.0
# 10                          2863.0
# ...                            ...
# 1014643                     4400.0
# 1014644                     4400.0
# 1014645                     4400.0
# 1014646                     4400.0
# 1014647                     4400.0
#
# [951644 rows x 11 columns]

# %% [markdown]
# ### Saving the encoded dataframe of mustard

# %%
df_encoded.to_csv('musencdf.csv')
