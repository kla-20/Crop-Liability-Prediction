# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Loading
# ## Bengal_Gram_Whole Data set!

# %%
df = pd.read_csv('/content/drive/MyDrive/crops_dataset/bengal_gram_whole.csv')
# Out:
# <ipython-input-2-e916c385df21>:1: DtypeWarning: Columns (0,1,2,3,4,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/crops_dataset/bengal_gram_whole.csv')

# %%
df
# Out:
#         District Name Market Name                      Group Commodity  \
# 0           Prakasam     Addanki   Bengal Gram(Gram)(Whole)     Other
# 1           Prakasam     Addanki   Bengal Gram(Gram)(Whole)     Other
# 2           Prakasam     Addanki   Bengal Gram(Gram)(Whole)     Other
# 3           Prakasam     Addanki   Bengal Gram(Gram)(Whole)     Other
# 4           Prakasam     Addanki   Bengal Gram(Gram)(Whole)     Other
# ...               ...         ...                        ...       ...
# 1014643           NaN         NaN                        NaN       NaN
# 1014644           NaN         NaN                        NaN       NaN
# 1014645           NaN         NaN                        NaN       NaN
# 1014646           NaN         NaN                        NaN       NaN
# 1014647           NaN         NaN                        NaN       NaN
#
#          Variety   Grade  Min Price (Rs/Quintal)  Max Price (Rs/Quintal)  \
# 0        Medium   3850.0                  3950.0                  3900.0
# 1        Medium   3800.0                  3900.0                  3850.0
# 2        Medium   3700.0                  3800.0                  3750.0
# 3        Medium   4100.0                  4150.0                  4130.0
# 4        Medium   4150.0                  4200.0                  4180.0
# ...          ...     ...                     ...                     ...
# 1014643      NaN     NaN                     NaN                     NaN
# 1014644      NaN     NaN                     NaN                     NaN
# 1014645      NaN     NaN                     NaN                     NaN
# 1014646      NaN     NaN                     NaN                     NaN
# 1014647      NaN     NaN                     NaN                     NaN
#
#         Modal Price (Rs/Quintal)      Price Date  Unnamed: 10
# 0               23-12-2017 00:00  Andhra Pradesh          NaN
# 1               22-12-2017 00:00  Andhra Pradesh          NaN
# 2               21-12-2017 00:00  Andhra Pradesh          NaN
# 3               20-12-2017 00:00  Andhra Pradesh          NaN
# 4               19-12-2017 00:00  Andhra Pradesh          NaN
# ...                          ...             ...          ...
# 1014643                      NaN             NaN          NaN
# 1014644                      NaN             NaN          NaN
# 1014645                      NaN             NaN          NaN
# 1014646                      NaN             NaN          NaN
# 1014647                      NaN             NaN          NaN
#
# [1014648 rows x 11 columns]

# %% [markdown]
# ### For this particular dataset the column names should be re-arranged and be done again

# %% [markdown]
# # Checking Column Details

# %%
df['District Name'].nunique()
# Out:
# 329

# %%
print(df['District Name'].unique())
# Out:
# ['Prakasam ' 'Kurnool ' 'Anantapur ' 'Cuddapah ' 'Vijayanagaram '
#  'Guntur ' 'Visakhapatnam ' 'Krishna ' 'West Godavari ' 'East Godavari '
#  'Srikakulam ' 'Nellore ' 'Barpeta ' 'Bangaigaon ' 'Cachar ' 'Sonitpur '
#  'Nagaon ' 'Dibrugarh ' 'Dhubri ' 'Goalpara ' 'Jorhat ' 'Karimganj '
#  'Darrang ' 'Nalbari ' 'Lakhimpur ' 'Kamrup ' 'Sibsagar ' 'Kokrajhar '
#  'Tinsukia ' 'Bhojpur ' 'Bhagalpur ' 'Kaimur/Bhabhua ' 'Patna ' 'Saharsa '
#  'Samastipur ' 'Raipur ' 'Surguja ' 'Jashpur ' 'Koria ' 'Balod '
#  'Raigarh ' 'Bastar ' 'Rajnandgaon ' 'Bemetara ' 'Balodabazar '
#  'Gariyaband ' 'Dhamtari ' 'Kondagaon ' 'Durg ' 'Korba ' 'Kabirdham '
#  'Mungeli ' 'Janjgir ' 'Narayanpur ' 'Bilaspur ' 'Balrampur ' 'Kanker '
#  'Surajpur ' 'Delhi ' 'Banaskanth ' 'Amreli ' 'Jamnagar ' 'Bhavnagar '
#  'Junagarh ' 'Sabarkantha ' 'Botad ' 'Surendranagar ' 'Dahod ' 'Rajkot '
#  'Panchmahals ' 'Patan ' 'Bharuch ' 'Surat ' 'Mehsana ' 'Mandi '
#  'Hamirpur ' 'Bhiwani ' 'Fatehabad ' 'Yamuna Nagar ' 'Sirsa '
#  'Mahendragarh-Narnaul ' 'Kurukshetra ' 'Jammu ' 'Bokaro '
#  'West Singbhum ' 'East Singhbhum ' 'Palamu ' 'Dhanbad ' 'Garhwa '
#  'Hazaribagh ' 'Jamtara ' 'Ranchi ' 'Koderma ' 'Latehar '
#  'Saraikela(Kharsanwa) ' 'Alappuzha ' 'Kollam ' 'Thiruvananthapuram '
#  'Alleppey ' 'Kottayam ' 'Palakad ' 'Malappuram ' 'Yavatmal ' 'Sangli '
#  'Amarawati ' 'Gadchiroli ' 'Ahmednagar ' 'Latur ' 'Hingoli ' 'Sholapur '
#  'Nandurbar ' 'Akola ' 'Raigad ' 'Jalgaon ' 'Jalana ' 'Beed ' 'Wardha '
#  'Aurangabad ' 'Pune ' 'Chandrapur ' 'Bhandara ' 'Nagpur ' 'Nanded '
#  'Parbhani ' 'Buldhana ' 'Nashik ' 'Dhule ' 'Kolhapur ' 'Osmanabad '
#  'Thane ' 'Vashim ' 'Satara ' 'Mumbai ' 'Gondiya ' 'Bishnupur '
#  'Imphal West ' 'Imphal East ' 'Chandel ' 'Thoubal ' 'Ratlam ' 'Shajapur '
#  'Bhind ' 'Alirajpur ' 'Satna ' 'Morena ' 'Badwani ' 'Anupur ' 'Guna '
#  'Ashoknagar ' 'Sehore ' 'Chhatarpur ' 'Shivpuri ' 'Ujjain ' 'Dhar '
#  'Khargone ' 'Dewas ' 'Rewa ' 'Balaghat ' 'Sagar ' 'Hoshangabad '
#  'Raisen ' 'Seoni ' 'Shehdol ' 'Betul ' 'Datia ' 'Gwalior ' 'Bhopal '
#  'Rajgarh ' 'Burhanpur ' 'Chhindwara ' 'Damoh ' 'Panna ' 'Dindori '
#  'Narsinghpur ' 'Vidisha ' 'Indore ' 'Harda ' 'Khandwa ' 'Jabalpur '
#  'Tikamgarh ' 'Neemuch ' 'Jhabua ' 'Katni ' 'Mandla ' 'Mandsaur '
#  'Sheopur ' 'Sidhi ' 'Singroli ' 'Umariya ' 'Bargarh ' 'Bolangir '
#  'Jajpur ' 'Kalahandi ' 'Malkangiri ' 'Nowarangpur ' 'Sundergarh '
#  'Gajapati ' 'Angul ' 'Fazilka ' 'Jalandhar ' 'Moga ' 'Bhatinda '
#  'Sangrur ' 'Hoshiarpur ' 'Muktsar ' 'Mohali ' 'Patiala ' 'kapurthala '
#  'Ferozpur ' 'Sirohi ' 'Ajmer ' 'Jhalawar ' 'Alwar ' 'Ganganagar '
#  'Baran ' 'Jaipur ' 'Bikaner ' 'Barmer ' 'Dausa ' 'Banswara ' 'Bharatpur '
#  'Hanumangarh ' 'Bhilwara ' 'Bundi ' 'Kota ' 'Jhunjunu ' 'Churu '
#  'Nagaur ' 'Tonk ' 'Dungarpur ' 'Chittorgarh ' 'Sikar ' 'Swai Madhopur '
#  'Karauli ' 'Pali ' 'Jodhpur ' 'Udaipur ' 'Mahbubnagar ' 'Adilabad '
#  'Ranga Reddy ' 'Nizamabad ' 'Khammam ' 'Karimnagar ' 'Medak ' 'Warangal '
#  'Ariyalur ' 'Madurai ' 'Coimbatore ' 'Villupuram ' 'Thiruvannamalai '
#  'Khowai ' 'Nanital ' 'Haridwar ' 'UdhamSinghNagar ' 'Dehradoon '
#  'Champawat ' 'Auraiya ' 'Agra ' 'Mirzapur ' 'Jalaun (Orai) ' 'Allahabad '
#  'Ambedkarnagar ' 'Aligarh ' 'Jyotiba Phule Nagar ' 'Maharajganj '
#  'Bulandshahar ' 'Bareilly ' 'Banda ' 'Azamgarh ' 'Badaun '
#  'Shahjahanpur ' 'Bahraich ' 'Ballia ' 'Unnao ' 'Lucknow ' 'Barabanki '
#  'Baghpat ' 'Deoria ' 'Basti ' 'Etawah ' 'Kaushambi ' 'Muradabad '
#  'Bijnor ' 'Fatehpur ' 'Chandauli ' 'Mahoba ' 'Farukhabad ' 'Kannuj '
#  'Jhansi ' 'Gorakhpur ' 'Kanpur ' 'Saharanpur ' 'Gautam Budh Nagar '
#  'Mau(Maunathbhanjan) ' 'Sonbhadra ' 'Etah ' 'Faizabad ' 'Firozabad '
#  'Ghazipur ' 'Ghaziabad ' 'Mainpuri ' 'Gonda ' 'Bhadohi(Sant Ravi Nagar) '
#  'Hathras ' 'Hardoi ' 'Sultanpur ' 'Jaunpur ' 'Raebarelli ' 'Chitrakut '
#  'Sant Kabir Nagar ' 'Muzaffarnagar ' 'Mathura ' 'Lalitpur ' 'Meerut '
#  'Rampur ' 'Siddharth Nagar ' 'Shravasti ' 'Pillibhit ' 'Pratapgarh '
#  'Sitapur ' 'Varanasi ' 'Burdwan ' 'Bankura ' 'Kolkata ' 'Nadia '
#  'Murshidabad ' 'Medinipur(W) ' 'Howrah ' 'Darjeeling ' nan]

# %% [markdown]
# #### District Name is fine

# %%
df['Market Name'].nunique()
# Out:
# 1193

# %%
print(df['Market Name'].unique())
# Out:
# ['Addanki ' 'Adoni ' 'Allagadda ' ... 'Ramkrishanpur(Howrah) ' 'Siliguri '
#  nan]

# %% [markdown]
# #### Market Name Seems Fine

# %%
df['Group'].unique()
# Out:
# array(['Bengal Gram(Gram)(Whole) ', nan], dtype=object)

# %% [markdown]
# #### This is basically name of the crop so we can drop this

# %%
df = df.drop('Group',axis=1)

# %%
df.head(5)
# Out:
#   District Name Market Name Commodity  Variety   Grade  \
# 0     Prakasam     Addanki     Other   Medium   3850.0
# 1     Prakasam     Addanki     Other   Medium   3800.0
# 2     Prakasam     Addanki     Other   Medium   3700.0
# 3     Prakasam     Addanki     Other   Medium   4100.0
# 4     Prakasam     Addanki     Other   Medium   4150.0
#
#    Min Price (Rs/Quintal)  Max Price (Rs/Quintal) Modal Price (Rs/Quintal)  \
# 0                  3950.0                  3900.0         23-12-2017 00:00
# 1                  3900.0                  3850.0         22-12-2017 00:00
# 2                  3800.0                  3750.0         21-12-2017 00:00
# 3                  4150.0                  4130.0         20-12-2017 00:00
# 4                  4200.0                  4180.0         19-12-2017 00:00
#
#        Price Date  Unnamed: 10
# 0  Andhra Pradesh          NaN
# 1  Andhra Pradesh          NaN
# 2  Andhra Pradesh          NaN
# 3  Andhra Pradesh          NaN
# 4  Andhra Pradesh          NaN

# %%
df['Commodity'].unique()
# Out:
# array(['Other ', 'Gulabi ', 'White (Whole) ', 'Bengal Gram (Split) ',
#        'Jawari/Local ', 'Desi (Whole) ', 'Average (Whole) ',
#        'Good (whole) ', 'Desi (F.A.Q. Split) ', 'Gulbarga Imp ',
#        'II Sort (Split) ', 'Ordinary (Split) ', 'GL-769 ', 'Bidar ',
#        'Gadag ', 'Kanta ', 'C-235 ', 'L-550 ', 'PBC-1 ', 'Chapa ',
#        'Small (Split) ', '999', 'CPF-2 ', 'Kabal (Split) ',
#        'Kabul Small ', 'Bengal Gram Dal ', 'Kabul ', 'Bold ', 'Medium ',
#        'Superior (Whole) ', 'Kabul Extra Bold ', 'PDC-3 ', nan],
#       dtype=object)

# %% [markdown]
# ### This column is actually the variety of the crop

# %%
import pandas as pd

# Assuming your DataFrame is named "df"
df.rename(columns={'Commodity': 'variety'}, inplace=True)

# %%
df.head(5)
# Out:
#   District Name Market Name variety  Variety   Grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium   3850.0                  3950.0
# 1     Prakasam     Addanki   Other   Medium   3800.0                  3900.0
# 2     Prakasam     Addanki   Other   Medium   3700.0                  3800.0
# 3     Prakasam     Addanki   Other   Medium   4100.0                  4150.0
# 4     Prakasam     Addanki   Other   Medium   4150.0                  4200.0
#
#    Max Price (Rs/Quintal) Modal Price (Rs/Quintal)      Price Date  \
# 0                  3900.0         23-12-2017 00:00  Andhra Pradesh
# 1                  3850.0         22-12-2017 00:00  Andhra Pradesh
# 2                  3750.0         21-12-2017 00:00  Andhra Pradesh
# 3                  4130.0         20-12-2017 00:00  Andhra Pradesh
# 4                  4180.0         19-12-2017 00:00  Andhra Pradesh
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df['variety'].nunique()
# Out:
# 32

# %% [markdown]
# #### variety also seems fine

# %%
df['Variety'].unique()
# Out:
# array(['Medium ', 'FAQ ', 'Large ', 'Small ', nan], dtype=object)

# %% [markdown]
# #### This column is the grade column so we will rename the column

# %%
import pandas as pd

# Assuming your DataFrame is named "df"
df.rename(columns={'Variety': 'grade'}, inplace=True)

# %%
df.head(5)
# Out:
#   District Name Market Name variety    grade   Grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium   3850.0                  3950.0
# 1     Prakasam     Addanki   Other   Medium   3800.0                  3900.0
# 2     Prakasam     Addanki   Other   Medium   3700.0                  3800.0
# 3     Prakasam     Addanki   Other   Medium   4100.0                  4150.0
# 4     Prakasam     Addanki   Other   Medium   4150.0                  4200.0
#
#    Max Price (Rs/Quintal) Modal Price (Rs/Quintal)      Price Date  \
# 0                  3900.0         23-12-2017 00:00  Andhra Pradesh
# 1                  3850.0         22-12-2017 00:00  Andhra Pradesh
# 2                  3750.0         21-12-2017 00:00  Andhra Pradesh
# 3                  4130.0         20-12-2017 00:00  Andhra Pradesh
# 4                  4180.0         19-12-2017 00:00  Andhra Pradesh
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# #### The ModalPrice , MaxPrice and MinPrice will be Renamed accordingly from the above seen dataframe

# %%
import pandas as pd

# Assuming your DataFrame is named "df"
df.rename(columns={'Grade': 'Min Price (Rs/Quintal)', 'Min Price (Rs/Quintal)': 'Max Price (Rs/Quintal)', 'Max Price (Rs/Quintal)': 'Modal Price (Rs/Quintal)','Modal Price (Rs/Quintal)': 'time stamp'}, inplace=True)

# %%
df.head(5)
# Out:
#   District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    Max Price (Rs/Quintal)  Modal Price (Rs/Quintal)        time stamp  \
# 0                  3950.0                    3900.0  23-12-2017 00:00
# 1                  3900.0                    3850.0  22-12-2017 00:00
# 2                  3800.0                    3750.0  21-12-2017 00:00
# 3                  4150.0                    4130.0  20-12-2017 00:00
# 4                  4200.0                    4180.0  19-12-2017 00:00
#
#        Price Date  Unnamed: 10
# 0  Andhra Pradesh          NaN
# 1  Andhra Pradesh          NaN
# 2  Andhra Pradesh          NaN
# 3  Andhra Pradesh          NaN
# 4  Andhra Pradesh          NaN

# %% [markdown]
# #### Similarly the Price Date Column which is actually the State column and we are going to remove the last column which is useless

# %%
df.rename(columns={'Price Date': 'State'}, inplace=True)
df = df.drop('Unnamed: 10',axis=1)

# %%
df.head(5)
# Out:
#   District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    Max Price (Rs/Quintal)  Modal Price (Rs/Quintal)        time stamp  \
# 0                  3950.0                    3900.0  23-12-2017 00:00
# 1                  3900.0                    3850.0  22-12-2017 00:00
# 2                  3800.0                    3750.0  21-12-2017 00:00
# 3                  4150.0                    4130.0  20-12-2017 00:00
# 4                  4200.0                    4180.0  19-12-2017 00:00
#
#             State
# 0  Andhra Pradesh
# 1  Andhra Pradesh
# 2  Andhra Pradesh
# 3  Andhra Pradesh
# 4  Andhra Pradesh

# %% [markdown]
# #### Take the time stamp column

# %%
df['time stamp'].nunique()
# Out:
# 5113

# %%
df['time stamp'].unique()
# Out:
# array(['23-12-2017 00:00', '22-12-2017 00:00', '21-12-2017 00:00', ...,
#        '28-10-2008 00:00', '04-05-2008 00:00', nan], dtype=object)

# %%
df['time stamp'].head(10)
# Out:
# 0    23-12-2017 00:00
# 1    22-12-2017 00:00
# 2    21-12-2017 00:00
# 3    20-12-2017 00:00
# 4    19-12-2017 00:00
# 5    18-12-2017 00:00
# 6    17-12-2017 00:00
# 7    16-12-2017 00:00
# 8    15-12-2017 00:00
# 9    14-12-2017 00:00
# Name: time stamp, dtype: object

# %%
import pandas as pd

# Assuming your column is named 'time stamp'
df['time stamp'] = pd.to_datetime(df['time stamp'], format='%d-%m-%Y %H:%M')

# Convert to string and remove the '00:00'
df['time stamp'] = df['time stamp'].dt.strftime('%d-%m-%Y')

# Convert back to datetime
df['time stamp'] = pd.to_datetime(df['time stamp'], format='%d-%m-%Y')

# %%
df.head(5)
# Out:
#   District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) time stamp           State
# 0                  3950.0                    3900.0 2017-12-23  Andhra Pradesh
# 1                  3900.0                    3850.0 2017-12-22  Andhra Pradesh
# 2                  3800.0                    3750.0 2017-12-21  Andhra Pradesh
# 3                  4150.0                    4130.0 2017-12-20  Andhra Pradesh
# 4                  4200.0                    4180.0 2017-12-19  Andhra Pradesh

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014648 entries, 0 to 1014647
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   District Name             940793 non-null  object
#  1   Market Name               940793 non-null  object
#  2   variety                   940793 non-null  object
#  3   grade                     940793 non-null  object
#  4   Min Price (Rs/Quintal)    940793 non-null  float64
#  5   Max Price (Rs/Quintal)    940793 non-null  float64
#  6   Modal Price (Rs/Quintal)  940793 non-null  float64
#  7   time stamp                940793 non-null  datetime64[ns]
#  8   State                     940793 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 69.7+ MB

# %%
df.rename(columns={'time stamp': 'Price Date'}, inplace=True)

# %%
df['Price Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.head(10)
# Out:
#   District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
# 5     Prakasam     Addanki   Other   Medium                   4100.0
# 6     Prakasam     Addanki   Other   Medium                   4050.0
# 7     Prakasam     Addanki   Other   Medium                   4100.0
# 8     Prakasam     Addanki   Other   Medium                   4050.0
# 9     Prakasam     Addanki   Other   Medium                   4100.0
#
#    Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) Price Date           State
# 0                  3950.0                    3900.0 2017-12-23  Andhra Pradesh
# 1                  3900.0                    3850.0 2017-12-22  Andhra Pradesh
# 2                  3800.0                    3750.0 2017-12-21  Andhra Pradesh
# 3                  4150.0                    4130.0 2017-12-20  Andhra Pradesh
# 4                  4200.0                    4180.0 2017-12-19  Andhra Pradesh
# 5                  4200.0                    4150.0 2017-12-18  Andhra Pradesh
# 6                  4100.0                    4080.0 2017-12-17  Andhra Pradesh
# 7                  4200.0                    4150.0 2017-12-16  Andhra Pradesh
# 8                  4150.0                    4100.0 2017-12-15  Andhra Pradesh
# 9                  4180.0                    4150.0 2017-12-14  Andhra Pradesh

# %% [markdown]
# # Pre-processing

# %%
df.shape
# Out:
# (1014648, 9)

# %%
rows = df.shape[0]
rows
# Out:
# 1014648

# %%
cols = df.shape[1]
cols
# Out:
# 9

# %%
df.isna().any()
# Out:
# District Name               True
# Market Name                 True
# variety                     True
# grade                       True
# Min Price (Rs/Quintal)      True
# Max Price (Rs/Quintal)      True
# Modal Price (Rs/Quintal)    True
# Price Date                  True
# State                       True
# dtype: bool

# %% [markdown]
# ## Dealing with Null Values!

# %%
# Number of Null values in the entire dataframe
df.isna().sum().sum()
# Out:
# 664695

# %%
## Checking number of null values in all the columns!

column_names = list(df.columns)
for i in range(0, len(column_names)):
  print(f"Column No: {i+1} = {column_names[i]} has {df[column_names[i]].isna().sum()} Null values!")
# Out:
# Column No: 1 = District Name has 73855 Null values!
# Column No: 2 = Market Name has 73855 Null values!
# Column No: 3 = variety has 73855 Null values!
# Column No: 4 = grade has 73855 Null values!
# Column No: 5 = Min Price (Rs/Quintal) has 73855 Null values!
# Column No: 6 = Max Price (Rs/Quintal) has 73855 Null values!
# Column No: 7 = Modal Price (Rs/Quintal) has 73855 Null values!
# Column No: 8 = Price Date has 73855 Null values!
# Column No: 9 = State has 73855 Null values!

# %% [markdown]
# We have columns that have the same number of null values so we will remove those particular rows

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
# List of columns with null values
columns_with_null = ['District Name', 'Market Name', 'variety', 'grade', 'Min Price (Rs/Quintal)', 'Max Price (Rs/Quintal)', 'Modal Price (Rs/Quintal)', 'Price Date', 'State']

# Create a new column indicating if all specified columns are null
df['all_columns_null'] = df[columns_with_null].isnull().all(axis=1)

# Filter the DataFrame to show rows where all specified columns are null
rows_with_all_null_columns = df[df['all_columns_null']]

# Display the result
rows_with_all_null_columns
# Out:
#         District Name Market Name variety grade  Min Price (Rs/Quintal)  \
# 940793            NaN         NaN     NaN   NaN                     NaN
# 940794            NaN         NaN     NaN   NaN                     NaN
# 940795            NaN         NaN     NaN   NaN                     NaN
# 940796            NaN         NaN     NaN   NaN                     NaN
# 940797            NaN         NaN     NaN   NaN                     NaN
# ...               ...         ...     ...   ...                     ...
# 1014643           NaN         NaN     NaN   NaN                     NaN
# 1014644           NaN         NaN     NaN   NaN                     NaN
# 1014645           NaN         NaN     NaN   NaN                     NaN
# 1014646           NaN         NaN     NaN   NaN                     NaN
# 1014647           NaN         NaN     NaN   NaN                     NaN
#
#          Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) Price Date State  \
# 940793                      NaN                       NaN        NaT   NaN
# 940794                      NaN                       NaN        NaT   NaN
# 940795                      NaN                       NaN        NaT   NaN
# 940796                      NaN                       NaN        NaT   NaN
# 940797                      NaN                       NaN        NaT   NaN
# ...                         ...                       ...        ...   ...
# 1014643                     NaN                       NaN        NaT   NaN
# 1014644                     NaN                       NaN        NaT   NaN
# 1014645                     NaN                       NaN        NaT   NaN
# 1014646                     NaN                       NaN        NaT   NaN
# 1014647                     NaN                       NaN        NaT   NaN
#
#          all_columns_null
# 940793               True
# 940794               True
# 940795               True
# 940796               True
# 940797               True
# ...                   ...
# 1014643              True
# 1014644              True
# 1014645              True
# 1014646              True
# 1014647              True
#
# [73855 rows x 10 columns]

# %% [markdown]
# #### We will remove those rows

# %%
import pandas as pd

# Assuming your DataFrame is named 'df'
# Select rows where 'District Name' column is null
rows_with_null_district = df[df['District Name'].isnull()]

# Display the result
rows_with_null_district
# Out:
#         District Name Market Name variety grade  Min Price (Rs/Quintal)  \
# 940793            NaN         NaN     NaN   NaN                     NaN
# 940794            NaN         NaN     NaN   NaN                     NaN
# 940795            NaN         NaN     NaN   NaN                     NaN
# 940796            NaN         NaN     NaN   NaN                     NaN
# 940797            NaN         NaN     NaN   NaN                     NaN
# ...               ...         ...     ...   ...                     ...
# 1014643           NaN         NaN     NaN   NaN                     NaN
# 1014644           NaN         NaN     NaN   NaN                     NaN
# 1014645           NaN         NaN     NaN   NaN                     NaN
# 1014646           NaN         NaN     NaN   NaN                     NaN
# 1014647           NaN         NaN     NaN   NaN                     NaN
#
#          Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) Price Date State  \
# 940793                      NaN                       NaN        NaT   NaN
# 940794                      NaN                       NaN        NaT   NaN
# 940795                      NaN                       NaN        NaT   NaN
# 940796                      NaN                       NaN        NaT   NaN
# 940797                      NaN                       NaN        NaT   NaN
# ...                         ...                       ...        ...   ...
# 1014643                     NaN                       NaN        NaT   NaN
# 1014644                     NaN                       NaN        NaT   NaN
# 1014645                     NaN                       NaN        NaT   NaN
# 1014646                     NaN                       NaN        NaT   NaN
# 1014647                     NaN                       NaN        NaT   NaN
#
#          all_columns_null
# 940793               True
# 940794               True
# 940795               True
# 940796               True
# 940797               True
# ...                   ...
# 1014643              True
# 1014644              True
# 1014645              True
# 1014646              True
# 1014647              True
#
# [73855 rows x 10 columns]

# %% [markdown]
# ### It looks like all those rows in the dataframe are having null values entered in all their column values!
#
# So we will remove those rows

# %%
df_cleaned = df.dropna(how='all')

# %%
df_cleaned = df_cleaned.drop('all_columns_null',axis=1)

# %%
df_cleaned
# Out:
#         District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0           Prakasam     Addanki   Other   Medium                   3850.0
# 1           Prakasam     Addanki   Other   Medium                   3800.0
# 2           Prakasam     Addanki   Other   Medium                   3700.0
# 3           Prakasam     Addanki   Other   Medium                   4100.0
# 4           Prakasam     Addanki   Other   Medium                   4150.0
# ...               ...         ...     ...      ...                     ...
# 1014643           NaN         NaN     NaN      NaN                     NaN
# 1014644           NaN         NaN     NaN      NaN                     NaN
# 1014645           NaN         NaN     NaN      NaN                     NaN
# 1014646           NaN         NaN     NaN      NaN                     NaN
# 1014647           NaN         NaN     NaN      NaN                     NaN
#
#          Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) Price Date  \
# 0                        3950.0                    3900.0 2017-12-23
# 1                        3900.0                    3850.0 2017-12-22
# 2                        3800.0                    3750.0 2017-12-21
# 3                        4150.0                    4130.0 2017-12-20
# 4                        4200.0                    4180.0 2017-12-19
# ...                         ...                       ...        ...
# 1014643                     NaN                       NaN        NaT
# 1014644                     NaN                       NaN        NaT
# 1014645                     NaN                       NaN        NaT
# 1014646                     NaN                       NaN        NaT
# 1014647                     NaN                       NaN        NaT
#
#                   State
# 0        Andhra Pradesh
# 1        Andhra Pradesh
# 2        Andhra Pradesh
# 3        Andhra Pradesh
# 4        Andhra Pradesh
# ...                 ...
# 1014643             NaN
# 1014644             NaN
# 1014645             NaN
# 1014646             NaN
# 1014647             NaN
#
# [1014648 rows x 9 columns]

# %%
df_cleaned = df_cleaned.dropna()

# %%
df_cleaned
# Out:
#        District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0          Prakasam     Addanki   Other   Medium                   3850.0
# 1          Prakasam     Addanki   Other   Medium                   3800.0
# 2          Prakasam     Addanki   Other   Medium                   3700.0
# 3          Prakasam     Addanki   Other   Medium                   4100.0
# 4          Prakasam     Addanki   Other   Medium                   4150.0
# ...              ...         ...     ...      ...                     ...
# 940788   Darjeeling    Siliguri   Other      FAQ                   6000.0
# 940789   Darjeeling    Siliguri   Other      FAQ                   6000.0
# 940790   Darjeeling    Siliguri   Other      FAQ                   6000.0
# 940791   Darjeeling    Siliguri   Other      FAQ                   6100.0
# 940792   Darjeeling    Siliguri   Other      FAQ                   6000.0
#
#         Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) Price Date  \
# 0                       3950.0                    3900.0 2017-12-23
# 1                       3900.0                    3850.0 2017-12-22
# 2                       3800.0                    3750.0 2017-12-21
# 3                       4150.0                    4130.0 2017-12-20
# 4                       4200.0                    4180.0 2017-12-19
# ...                        ...                       ...        ...
# 940788                  6400.0                    6200.0 2015-12-09
# 940789                  6400.0                    6200.0 2015-12-08
# 940790                  6400.0                    6200.0 2015-12-04
# 940791                  6600.0                    6400.0 2015-12-03
# 940792                  6600.0                    6300.0 2015-12-02
#
#                  State  all_columns_null
# 0       Andhra Pradesh             False
# 1       Andhra Pradesh             False
# 2       Andhra Pradesh             False
# 3       Andhra Pradesh             False
# 4       Andhra Pradesh             False
# ...                ...               ...
# 940788     West Bengal             False
# 940789     West Bengal             False
# 940790     West Bengal             False
# 940791     West Bengal             False
# 940792     West Bengal             False
#
# [940793 rows x 10 columns]

# %%
df_cleaned['all_columns_null'].unique()
# Out:
# array([False])

# %% [markdown]
# So we will check if all the columns are having the null values again!

# %%
df_cleaned.shape
# Out:
# (940793, 10)

# %%
rows = df_cleaned.shape[0]
rows
# Out:
# 940793

# %%
cols = df_cleaned.shape[1]
cols
# Out:
# 10

# %%
df_cleaned.isna().any()
# Out:
# District Name               False
# Market Name                 False
# variety                     False
# grade                       False
# Min Price (Rs/Quintal)      False
# Max Price (Rs/Quintal)      False
# Modal Price (Rs/Quintal)    False
# Price Date                  False
# State                       False
# all_columns_null            False
# dtype: bool

# %% [markdown]
# ## Dealing with Null Values!

# %%
# Number of Null values in the entire dataframe
df_cleaned.isna().sum().sum()
# Out:
# 0

# %%
## Checking number of null values in all the columns!

column_names = list(df_cleaned.columns)
for i in range(0, len(column_names)):
  print(f"Column No: {i+1} = {column_names[i]} has {df_cleaned[column_names[i]].isna().sum()} Null values!")
# Out:
# Column No: 1 = District Name has 0 Null values!
# Column No: 2 = Market Name has 0 Null values!
# Column No: 3 = variety has 0 Null values!
# Column No: 4 = grade has 0 Null values!
# Column No: 5 = Min Price (Rs/Quintal) has 0 Null values!
# Column No: 6 = Max Price (Rs/Quintal) has 0 Null values!
# Column No: 7 = Modal Price (Rs/Quintal) has 0 Null values!
# Column No: 8 = Price Date has 0 Null values!
# Column No: 9 = State has 0 Null values!
# Column No: 10 = all_columns_null has 0 Null values!

# %% [markdown]
# #### So No Null values

# %% [markdown]
# # So this cleaned dataset is our proper dataset

# %%
df = df_cleaned

# %%
df = df.drop('all_columns_null', axis =1)

# %%
df.head(5)
# Out:
#   District Name Market Name variety    grade  Min Price (Rs/Quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    Max Price (Rs/Quintal)  Modal Price (Rs/Quintal) Price Date           State
# 0                  3950.0                    3900.0 2017-12-23  Andhra Pradesh
# 1                  3900.0                    3850.0 2017-12-22  Andhra Pradesh
# 2                  3800.0                    3750.0 2017-12-21  Andhra Pradesh
# 3                  4150.0                    4130.0 2017-12-20  Andhra Pradesh
# 4                  4200.0                    4180.0 2017-12-19  Andhra Pradesh

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # I will save this dataset now!

# %%
df.to_csv('bengal_gram_whole_cleaned.csv', index=False)

# %% [markdown]
# # Unique values in the columns of the dataset

# %%
# No of unique values in all the columns

column_names = list(df.columns)

for i in range(0, len(column_names)):
  print(f'The column {column_names[i]} has {df[column_names[i]].nunique()} unique values!')
# Out:
# The column District Name has 329 unique values!
# The column Market Name has 1193 unique values!
# The column variety has 32 unique values!
# The column grade has 4 unique values!
# The column Min Price (Rs/Quintal) has 6605 unique values!
# The column Max Price (Rs/Quintal) has 7748 unique values!
# The column Modal Price (Rs/Quintal) has 7467 unique values!
# The column Price Date has 5113 unique values!
# The column State has 23 unique values!

# %%
df.columns
# Out:
# Index(['District Name', 'Market Name', 'variety', 'grade',
#        'Min Price (Rs/Quintal)', 'Max Price (Rs/Quintal)',
#        'Modal Price (Rs/Quintal)', 'Price Date', 'State'],
#       dtype='object')

# %%
import pandas as pd

# Assuming df is your DataFrame
df.columns = df.columns.str.replace(' ', '_').str.lower()

# Alternatively, you can use the following code to replace spaces with underscores and convert to lowercase
# df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# Now, the column names will be in lowercase and with underscores instead of spaces
print(df.columns)
# Out:
# Index(['district_name', 'market_name', 'variety', 'grade',
#        'min_price_(rs/quintal)', 'max_price_(rs/quintal)',
#        'modal_price_(rs/quintal)', 'price_date', 'state'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state price_date_copy  month  year
# 0  Andhra Pradesh      2017-12-23     12  2017
# 1  Andhra Pradesh      2017-12-22     12  2017
# 2  Andhra Pradesh      2017-12-21     12  2017
# 3  Andhra Pradesh      2017-12-20     12  2017
# 4  Andhra Pradesh      2017-12-19     12  2017

# %%
df['price_date_copy'] = df['price_date'].astype(str)

# %%
df['month'] = df['price_date_copy'].str[5:7].astype(int)
df['year'] = df['price_date_copy'].str[0:4].astype(int)

# %%
df.head(3)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
#
#             state price_date_copy  month  year
# 0  Andhra Pradesh      2017-12-23     12  2017
# 1  Andhra Pradesh      2017-12-22     12  2017
# 2  Andhra Pradesh      2017-12-21     12  2017

# %%
df = df.drop('price_date_copy', axis=1)

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year
# 0  Andhra Pradesh     12  2017
# 1  Andhra Pradesh     12  2017
# 2  Andhra Pradesh     12  2017
# 3  Andhra Pradesh     12  2017
# 4  Andhra Pradesh     12  2017

# %%
# Convert 'price_date' to timestamp
df['price_date'] = pd.to_datetime(df['price_date'], format='%d-%m-%Y')

# Convert 'month' and 'year' to int
df['month'] = df['month'].astype(int)
df['year'] = df['year'].astype(int)

# Display the updated DataFrame
print(df.dtypes)
# Out:
# district_name                       object
# market_name                         object
# variety                             object
# grade                               object
# min_price_(rs/quintal)             float64
# max_price_(rs/quintal)             float64
# modal_price_(rs/quintal)           float64
# price_date                  datetime64[ns]
# state                               object
# month                                int64
# year                                 int64
# dtype: object

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year
# 0  Andhra Pradesh     12  2017
# 1  Andhra Pradesh     12  2017
# 2  Andhra Pradesh     12  2017
# 3  Andhra Pradesh     12  2017
# 4  Andhra Pradesh     12  2017

# %%
import pandas as pd

# Assuming your DataFrame is named 'df' and 'price_date' is in datetime format
df['price_date'] = pd.to_datetime(df['price_date'])

# Format 'price_date' as 'DD-MM-YYYY'
df['price_date'] = df['price_date'].dt.strftime('%d-%m-%Y')

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal)  price_date  \
# 0                  3950.0                    3900.0  23-12-2017
# 1                  3900.0                    3850.0  22-12-2017
# 2                  3800.0                    3750.0  21-12-2017
# 3                  4150.0                    4130.0  20-12-2017
# 4                  4200.0                    4180.0  19-12-2017
#
#             state  month  year
# 0  Andhra Pradesh     12  2017
# 1  Andhra Pradesh     12  2017
# 2  Andhra Pradesh     12  2017
# 3  Andhra Pradesh     12  2017
# 4  Andhra Pradesh     12  2017

# %%
# Convert 'price_date' column to datetime format
df['price_date'] = pd.to_datetime(df['price_date'], format='%d-%m-%Y')

# %%
print(df.dtypes)
# Out:
# district_name                       object
# market_name                         object
# variety                             object
# grade                               object
# min_price_(rs/quintal)             float64
# max_price_(rs/quintal)             float64
# modal_price_(rs/quintal)           float64
# price_date                  datetime64[ns]
# state                               object
# month                                int64
# year                                 int64
# dtype: object

# %%
df_copy = df

# %% [markdown]
# # Encoding Columns

# %% [markdown]
# ## district Name

# %%
df['district_name'].nunique()
# Out:
# 329

# %%
value_counts = df['district_name'].value_counts()

# %%
value_counts
# Out:
# Prakasam        26575
# Kurnool         26419
# Ganganagar      22416
# Ahmednagar      21115
# Buldhana        20182
#                 ...
# Mehsana             1
# Moga                1
# Murshidabad         1
# Madurai             1
# Darrang             1
# Name: district_name, Length: 329, dtype: int64

# %%
district_name_frequency = df['district_name'].value_counts(normalize=False)

# Create a new column with encoded values
df['district_name_encoded'] = df['district_name'].map(district_name_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year  district_name_encoded
# 0  Andhra Pradesh     12  2017                  26575
# 1  Andhra Pradesh     12  2017                  26575
# 2  Andhra Pradesh     12  2017                  26575
# 3  Andhra Pradesh     12  2017                  26575
# 4  Andhra Pradesh     12  2017                  26575

# %% [markdown]
# ## market name

# %%
df['market_name'].nunique()
# Out:
# 1193

# %%
value_counts = df['market_name'].value_counts()

# %%
value_counts
# Out:
# Dahod             8001
# Dewas             5397
# Ranchi            4945
# Bareilly          4941
# Nandikotkur       4656
#                   ...
# Visakhapatnam        1
# Surajpur             1
# Kagaznagar           1
# Bhind                1
# Vinukonda            1
# Name: market_name, Length: 1193, dtype: int64

# %%
market_name_frequency = df['market_name'].value_counts(normalize=False)

# Create a new column with encoded values
df['market_name_encoded'] = df['market_name'].map(market_name_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year  district_name_encoded  market_name_encoded
# 0  Andhra Pradesh     12  2017                  26575                 3364
# 1  Andhra Pradesh     12  2017                  26575                 3364
# 2  Andhra Pradesh     12  2017                  26575                 3364
# 3  Andhra Pradesh     12  2017                  26575                 3364
# 4  Andhra Pradesh     12  2017                  26575                 3364

# %% [markdown]
# ## variety

# %%
df['variety'].nunique()
# Out:
# 32

# %%
value_counts = df['variety'].value_counts()

# %%
variety_frequency = df['variety'].value_counts(normalize=False)

# Create a new column with encoded values
df['variety_encoded'] = df['variety'].map(variety_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh     12  2017                  26575                 3364
# 1  Andhra Pradesh     12  2017                  26575                 3364
# 2  Andhra Pradesh     12  2017                  26575                 3364
# 3  Andhra Pradesh     12  2017                  26575                 3364
# 4  Andhra Pradesh     12  2017                  26575                 3364
#
#    variety_encoded
# 0           485527
# 1           485527
# 2           485527
# 3           485527
# 4           485527

# %% [markdown]
# ## grade

# %%
df['grade'].unique()
# Out:
# array(['Medium ', 'FAQ ', 'Large ', 'Small '], dtype=object)

# %%
value_counts = df['grade'].value_counts()
value_counts
# Out:
# FAQ        891780
# Medium      47303
# Large        1599
# Small         111
# Name: grade, dtype: int64

# %%
grade_frequency = df['grade'].value_counts(normalize=False)

# Create a new column with encoded values
df['grade_encoded'] = df['grade'].map(grade_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh     12  2017                  26575                 3364
# 1  Andhra Pradesh     12  2017                  26575                 3364
# 2  Andhra Pradesh     12  2017                  26575                 3364
# 3  Andhra Pradesh     12  2017                  26575                 3364
# 4  Andhra Pradesh     12  2017                  26575                 3364
#
#    variety_encoded  grade_encoded
# 0           485527          47303
# 1           485527          47303
# 2           485527          47303
# 3           485527          47303
# 4           485527          47303

# %% [markdown]
# ## state

# %%
df['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chattisgarh', 'NCT of Delhi',
#        'Gujarat', 'Himachal Pradesh', 'Haryana', 'Jammu and Kashmir',
#        'Jharkhand', 'Kerala', 'Maharashtra', 'Manipur', 'Madhya Pradesh',
#        'Odisha', 'Punjab', 'Rajasthan', 'Telangana', 'Tamil Nadu',
#        'Tripura', 'Uttrakhand', 'Uttar Pradesh', 'West Bengal'],
#       dtype=object)

# %%
value_counts = df['state'].value_counts()
value_counts
# Out:
# Uttar Pradesh        248843
# Maharashtra          245142
# Madhya Pradesh       152933
# Rajasthan            116305
# Andhra Pradesh        73431
# Gujarat               26366
# Jharkhand             21957
# Kerala                16513
# Chattisgarh            9548
# Assam                  9106
# Telangana              6040
# Manipur                5798
# West Bengal            3038
# Tamil Nadu             1600
# Uttrakhand             1037
# Bihar                   761
# NCT of Delhi            619
# Haryana                 586
# Punjab                  407
# Tripura                 348
# Jammu and Kashmir       265
# Odisha                   97
# Himachal Pradesh         53
# Name: state, dtype: int64

# %%
state_frequency = df['state'].value_counts(normalize=False)

# Create a new column with encoded values
df['state_encoded'] = df['state'].map(state_frequency)

# %%
df.head(5)
# Out:
#   district_name market_name variety    grade  min_price_(rs/quintal)  \
# 0     Prakasam     Addanki   Other   Medium                   3850.0
# 1     Prakasam     Addanki   Other   Medium                   3800.0
# 2     Prakasam     Addanki   Other   Medium                   3700.0
# 3     Prakasam     Addanki   Other   Medium                   4100.0
# 4     Prakasam     Addanki   Other   Medium                   4150.0
#
#    max_price_(rs/quintal)  modal_price_(rs/quintal) price_date  \
# 0                  3950.0                    3900.0 2017-12-23
# 1                  3900.0                    3850.0 2017-12-22
# 2                  3800.0                    3750.0 2017-12-21
# 3                  4150.0                    4130.0 2017-12-20
# 4                  4200.0                    4180.0 2017-12-19
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh     12  2017                  26575                 3364
# 1  Andhra Pradesh     12  2017                  26575                 3364
# 2  Andhra Pradesh     12  2017                  26575                 3364
# 3  Andhra Pradesh     12  2017                  26575                 3364
# 4  Andhra Pradesh     12  2017                  26575                 3364
#
#    variety_encoded  grade_encoded  state_encoded
# 0           485527          47303          73431
# 1           485527          47303          73431
# 2           485527          47303          73431
# 3           485527          47303          73431
# 4           485527          47303          73431

# %%
df.rename(columns={
    'min_price_(rs/quintal)': 'min_price_(rs./quintal)',
    'max_price_(rs/quintal)': 'max_price_(rs./quintal)',
    'modal_price_(rs/quintal)': 'modal_price_(rs./quintal)'
}, inplace=True)

# %%
df.head(2)
# Out:
#   district_name market_name variety    grade  min_price_(rs./quintal)  \
# 0     Prakasam     Addanki   Other   Medium                    3850.0
# 1     Prakasam     Addanki   Other   Medium                    3800.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal) price_date  \
# 0                   3950.0                     3900.0 2017-12-23
# 1                   3900.0                     3850.0 2017-12-22
#
#             state  month  year  district_name_encoded  market_name_encoded  \
# 0  Andhra Pradesh     12  2017                  26575                 3364
# 1  Andhra Pradesh     12  2017                  26575                 3364
#
#    variety_encoded  grade_encoded  state_encoded
# 0           485527          47303          73431
# 1           485527          47303          73431

# %% [markdown]
# # Taking only the Encoded columns

# %%
df_encoded = df[['district_name_encoded', 'market_name_encoded', 'variety_encoded', 'grade_encoded', 'state_encoded', 'month', 'year', 'price_date', 'min_price_(rs./quintal)', 'max_price_(rs./quintal)', 'modal_price_(rs./quintal)']]

# %% [markdown]
# # Encoded Dataset

# %%
df_encoded.head(8)
# Out:
#    district_name_encoded  market_name_encoded  variety_encoded  grade_encoded  \
# 0                  26575                 3364           485527          47303
# 1                  26575                 3364           485527          47303
# 2                  26575                 3364           485527          47303
# 3                  26575                 3364           485527          47303
# 4                  26575                 3364           485527          47303
# 5                  26575                 3364           485527          47303
# 6                  26575                 3364           485527          47303
# 7                  26575                 3364           485527          47303
#
#    state_encoded  month  year price_date  min_price_(rs./quintal)  \
# 0          73431     12  2017 2017-12-23                   3850.0
# 1          73431     12  2017 2017-12-22                   3800.0
# 2          73431     12  2017 2017-12-21                   3700.0
# 3          73431     12  2017 2017-12-20                   4100.0
# 4          73431     12  2017 2017-12-19                   4150.0
# 5          73431     12  2017 2017-12-18                   4100.0
# 6          73431     12  2017 2017-12-17                   4050.0
# 7          73431     12  2017 2017-12-16                   4100.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal)
# 0                   3950.0                     3900.0
# 1                   3900.0                     3850.0
# 2                   3800.0                     3750.0
# 3                   4150.0                     4130.0
# 4                   4200.0                     4180.0
# 5                   4200.0                     4150.0
# 6                   4100.0                     4080.0
# 7                   4200.0                     4150.0

# %% [markdown]
# # Heat Map

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_encoded is your DataFrame
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(df_encoded.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-135-f636cb7d937b>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df_encoded.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# %% [markdown]
# # Models and Evaluation

# %%
# Evaluation Metrics

def Emetrics(y_test,y_pred):
  from sklearn import metrics

  # Print result of MAE
  print(f"Mean Absoulute error is : {metrics.mean_absolute_error(y_test,y_pred)}")

  # Print result of RMSE
  print(f"Root Mean Square error is: {np.sqrt(metrics.mean_squared_error(y_test,y_pred))}")

  # Print result of R2
  print(f"R2 score is: {metrics.r2_score(y_test,y_pred)}")

# %%
df_encoded.head(5)
# Out:
#    district_name_encoded  market_name_encoded  variety_encoded  grade_encoded  \
# 0                  26575                 3364           485527          47303
# 1                  26575                 3364           485527          47303
# 2                  26575                 3364           485527          47303
# 3                  26575                 3364           485527          47303
# 4                  26575                 3364           485527          47303
#
#    state_encoded  month  year price_date  min_price_(rs./quintal)  \
# 0          73431     12  2017 2017-12-23                   3850.0
# 1          73431     12  2017 2017-12-22                   3800.0
# 2          73431     12  2017 2017-12-21                   3700.0
# 3          73431     12  2017 2017-12-20                   4100.0
# 4          73431     12  2017 2017-12-19                   4150.0
#
#    max_price_(rs./quintal)  modal_price_(rs./quintal)
# 0                   3950.0                     3900.0
# 1                   3900.0                     3850.0
# 2                   3800.0                     3750.0
# 3                   4150.0                     4130.0
# 4                   4200.0                     4180.0

# %% [markdown]
# # Outlier Removing rows

# %%
import pandas as pd
from scipy.stats import zscore

# Assuming df_encoded is your DataFrame
# Replace 'df_encoded' with your actual DataFrame name

# Function to identify outliers using Z-score
def identify_outliers_zscore(df, threshold=3):
    z_scores = zscore(df.select_dtypes(include=['float64', 'int64']))
    outliers = (abs(z_scores) > threshold).any(axis=1)
    return outliers

# Identify outliers
outliers = identify_outliers_zscore(df_encoded)

# Remove rows with outliers
df_cleaned = df_encoded[~outliers]

# %%
df_encoded = df_cleaned

# %% [markdown]
# ## Standardizing values (min-max scalar)

# %%
df_encoded
# Out:
#         district_name_encoded  market_name_encoded  variety_encoded  \
# 1050                    26575                 3364            31260
# 1051                    26575                 3364            31260
# 1054                    26575                 3364            31260
# 1055                    26575                 3364            31260
# 1056                    26575                 3364            31260
# ...                       ...                  ...              ...
# 940788                   1099                 1099           485527
# 940789                   1099                 1099           485527
# 940790                   1099                 1099           485527
# 940791                   1099                 1099           485527
# 940792                   1099                 1099           485527
#
#         grade_encoded  state_encoded  month  year price_date  \
# 1050           891780          73431      1  2015 2015-01-22
# 1051           891780          73431      1  2015 2015-01-21
# 1054           891780          73431      1  2015 2015-01-18
# 1055           891780          73431      1  2015 2015-01-17
# 1056           891780          73431      1  2015 2015-01-17
# ...               ...            ...    ...   ...        ...
# 940788         891780           3038     12  2015 2015-12-09
# 940789         891780           3038     12  2015 2015-12-08
# 940790         891780           3038     12  2015 2015-12-04
# 940791         891780           3038     12  2015 2015-12-03
# 940792         891780           3038     12  2015 2015-12-02
#
#         min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 1050                     3100.0                   3100.0
# 1051                     3100.0                   3100.0
# 1054                     3100.0                   3100.0
# 1055                     3100.0                   3100.0
# 1056                     3100.0                   3100.0
# ...                         ...                      ...
# 940788                   6000.0                   6400.0
# 940789                   6000.0                   6400.0
# 940790                   6000.0                   6400.0
# 940791                   6100.0                   6600.0
# 940792                   6000.0                   6600.0
#
#         modal_price_(rs./quintal)
# 1050                       3100.0
# 1051                       3100.0
# 1054                       3100.0
# 1055                       3100.0
# 1056                       3100.0
# ...                           ...
# 940788                     6200.0
# 940789                     6200.0
# 940790                     6200.0
# 940791                     6400.0
# 940792                     6300.0
#
# [870087 rows x 11 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df_encoded is your DataFrame
# Replace 'df_encoded' with your actual DataFrame name

# Columns to be scaled
columns_to_scale = ['district_name_encoded', 'market_name_encoded', 'variety_encoded', 'grade_encoded', 'state_encoded']

# Min-Max Scaling
min_max_scaler = MinMaxScaler()
df_encoded[columns_to_scale] = min_max_scaler.fit_transform(df_encoded[columns_to_scale])

# %%
df_encoded.head(5)
# Out:
#       district_name_encoded  market_name_encoded  variety_encoded  \
# 1050                    1.0             0.623239         0.064378
# 1051                    1.0             0.623239         0.064378
# 1054                    1.0             0.623239         0.064378
# 1055                    1.0             0.623239         0.064378
# 1056                    1.0             0.623239         0.064378
#
#       grade_encoded  state_encoded  month  year price_date  \
# 1050            0.0        0.29494      1  2015 2015-01-22
# 1051            0.0        0.29494      1  2015 2015-01-21
# 1054            0.0        0.29494      1  2015 2015-01-18
# 1055            0.0        0.29494      1  2015 2015-01-17
# 1056            0.0        0.29494      1  2015 2015-01-17
#
#       min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 1050                   3100.0                   3100.0
# 1051                   3100.0                   3100.0
# 1054                   3100.0                   3100.0
# 1055                   3100.0                   3100.0
# 1056                   3100.0                   3100.0
#
#       modal_price_(rs./quintal)
# 1050                     3100.0
# 1051                     3100.0
# 1054                     3100.0
# 1055                     3100.0
# 1056                     3100.0

# %% [markdown]
# ## Forward Stepwise Selection

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

def forward_stepwise_selection(X, y):
    # Initialize an empty set of features
    selected_features = []

    # Initialize a linear regression model
    model = LinearRegression()

    # Loop until all features have been added to the model
    while len(selected_features) < X.shape[1]:

        # Initialize variables to keep track of best feature and score
        best_feature = None
        best_score = -np.inf

        # Loop over all remaining features
        for feature in X.columns:
            if feature not in selected_features:
                # Fit a model with the current set of features plus the new feature
                current_features = selected_features + [feature]
                X_current = X[current_features]
                model.fit(X_current, y)

                # Calculate the score for the new model
                y_pred = model.predict(X_current)
                score = r2_score(y, y_pred)

                # Keep track of the best feature and score
                if score > best_score:
                    best_feature = feature
                    best_score = score

        # Add the best feature to the selected features and print the result
        selected_features.append(best_feature)
        print(f'Selected feature: {best_feature}, Score: {best_score:.4f}')

    return selected_features

# %%
X = df_encoded.loc[:, ['district_name_encoded',	'market_name_encoded',	'variety_encoded',	'grade_encoded',	'state_encoded',	'month',	'year']]
y = df_encoded.loc[:, ['min_price_(rs./quintal)',	'max_price_(rs./quintal)',	'modal_price_(rs./quintal)']]

# %%
print(forward_stepwise_selection(X, y))
# Out:
# Selected feature: year, Score: 0.3051
# Selected feature: state_encoded, Score: 0.3273
# Selected feature: district_name_encoded, Score: 0.3344
# Selected feature: month, Score: 0.3404
# Selected feature: market_name_encoded, Score: 0.3454
# Selected feature: variety_encoded, Score: 0.3483
# Selected feature: grade_encoded, Score: 0.3483
# ['year', 'state_encoded', 'district_name_encoded', 'month', 'market_name_encoded', 'variety_encoded', 'grade_encoded']

# %% [markdown]
# ### All the features are closely important

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .4, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
lnregressor = LinearRegression()
lnregressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lnregressor.predict(X_test)
y_pred
# Out:
# array([[3497.76577859, 3789.02086314, 3897.38364515],
#        [4338.86170483, 4720.53095979, 4607.28583867],
#        [2455.34402367, 2661.32371009, 3628.52277202],
#        ...,
#        [2855.20626328, 3087.91489187, 3671.92791153],
#        [3961.4483139 , 4242.21984618, 4726.98084758],
#        [3890.37106405, 4173.33223087, 4491.42544575]])

# %%
# Evaluation metrics for Linear Regression
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 947.5369168374423
# Root Mean Square error is: 1283.6478365108594
# R2 score is: 0.348257987507485

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

dt_regressor = DecisionTreeRegressor(
    random_state=42,
    max_depth=50,
    min_samples_split=3,
    min_samples_leaf=5,
    max_features='auto',
    criterion='friedman_mse'
)

# Train the model using the training sets
dt_regressor.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = dt_regressor.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(

# %%
# Evaluation metrics for Linear Regression
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 179.62231872958708
# Root Mean Square error is: 386.87352742336157
# R2 score is: 0.9410394060832398

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(
    n_estimators=200,  # Reduced number of trees
    max_depth=30,  # Reduced maximum depth
    random_state=42,
    bootstrap=True,
    warm_start=True,  # Enable incremental training
    n_jobs=-1  # Utilize all CPU cores
)

# Train the model
rf_regressor.fit(X_train, y_train)

# Make predictions
y_pred = rf_regressor.predict(X_test)

# %%
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 171.46631540005941
# Root Mean Square error is: 370.82916845796177
# R2 score is: 0.9456754193239011

# %% [markdown]
# ## XgBoost Regression

# %%
from xgboost import XGBRegressor
# Create the XGBoost regression model
xg_regressor = XGBRegressor(n_estimators=250, learning_rate=0.37,random_state=42)

# Train the model
xg_regressor.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = xg_regressor.predict(X_test)

# Evaluate the model's performance
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 250.31593921153365
# Root Mean Square error is: 442.75469057722506
# R2 score is: 0.9239741156095497

# %% [markdown]
# ## KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# Create the KNN regression model
knn_regressor = KNeighborsRegressor(n_neighbors=5)  # You can adjust the number of neighbors as needed

# Train the model
knn_regressor.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = knn_regressor.predict(X_test)


# Evaluate the model's performance
Emetrics(y_test,y_pred)
# Out:
# Mean Absoulute error is : 194.9436859204758
# Root Mean Square error is: 433.8636540915359
# R2 score is: 0.9267348077284936

# %% [markdown]
# # Datasets of Bengal_Gram_Whole

# %% [markdown]
# ## Main

# %%
df
# Out:
#        district_name market_name variety    grade  min_price_(rs./quintal)  \
# 0          Prakasam     Addanki   Other   Medium                    3850.0
# 1          Prakasam     Addanki   Other   Medium                    3800.0
# 2          Prakasam     Addanki   Other   Medium                    3700.0
# 3          Prakasam     Addanki   Other   Medium                    4100.0
# 4          Prakasam     Addanki   Other   Medium                    4150.0
# ...              ...         ...     ...      ...                      ...
# 940788   Darjeeling    Siliguri   Other      FAQ                    6000.0
# 940789   Darjeeling    Siliguri   Other      FAQ                    6000.0
# 940790   Darjeeling    Siliguri   Other      FAQ                    6000.0
# 940791   Darjeeling    Siliguri   Other      FAQ                    6100.0
# 940792   Darjeeling    Siliguri   Other      FAQ                    6000.0
#
#         max_price_(rs./quintal)  modal_price_(rs./quintal) price_date  \
# 0                        3950.0                     3900.0 2017-12-23
# 1                        3900.0                     3850.0 2017-12-22
# 2                        3800.0                     3750.0 2017-12-21
# 3                        4150.0                     4130.0 2017-12-20
# 4                        4200.0                     4180.0 2017-12-19
# ...                         ...                        ...        ...
# 940788                   6400.0                     6200.0 2015-12-09
# 940789                   6400.0                     6200.0 2015-12-08
# 940790                   6400.0                     6200.0 2015-12-04
# 940791                   6600.0                     6400.0 2015-12-03
# 940792                   6600.0                     6300.0 2015-12-02
#
#                  state  month  year  district_name_encoded  \
# 0       Andhra Pradesh     12  2017                  26575
# 1       Andhra Pradesh     12  2017                  26575
# 2       Andhra Pradesh     12  2017                  26575
# 3       Andhra Pradesh     12  2017                  26575
# 4       Andhra Pradesh     12  2017                  26575
# ...                ...    ...   ...                    ...
# 940788     West Bengal     12  2015                   1099
# 940789     West Bengal     12  2015                   1099
# 940790     West Bengal     12  2015                   1099
# 940791     West Bengal     12  2015                   1099
# 940792     West Bengal     12  2015                   1099
#
#         market_name_encoded  variety_encoded  grade_encoded  state_encoded
# 0                      3364           485527          47303          73431
# 1                      3364           485527          47303          73431
# 2                      3364           485527          47303          73431
# 3                      3364           485527          47303          73431
# 4                      3364           485527          47303          73431
# ...                     ...              ...            ...            ...
# 940788                 1099           485527         891780           3038
# 940789                 1099           485527         891780           3038
# 940790                 1099           485527         891780           3038
# 940791                 1099           485527         891780           3038
# 940792                 1099           485527         891780           3038
#
# [940793 rows x 16 columns]

# %% [markdown]
# ### Saving the dataframe of bengal_gram_whole
#
# > Indented block

# %%
df.to_csv('bengal_gram_wholedf.csv')

# %% [markdown]
# ## Encoded

# %%
df_encoded
# Out:
#         district_name_encoded  market_name_encoded  variety_encoded  \
# 1050                 1.000000             0.623239         0.064378
# 1051                 1.000000             0.623239         0.064378
# 1054                 1.000000             0.623239         0.064378
# 1055                 1.000000             0.623239         0.064378
# 1056                 1.000000             0.623239         0.064378
# ...                       ...                  ...              ...
# 940788               0.041319             0.203484         1.000000
# 940789               0.041319             0.203484         1.000000
# 940790               0.041319             0.203484         1.000000
# 940791               0.041319             0.203484         1.000000
# 940792               0.041319             0.203484         1.000000
#
#         grade_encoded  state_encoded  month  year price_date  \
# 1050              0.0       0.294940      1  2015 2015-01-22
# 1051              0.0       0.294940      1  2015 2015-01-21
# 1054              0.0       0.294940      1  2015 2015-01-18
# 1055              0.0       0.294940      1  2015 2015-01-17
# 1056              0.0       0.294940      1  2015 2015-01-17
# ...               ...            ...    ...   ...        ...
# 940788            0.0       0.011998     12  2015 2015-12-09
# 940789            0.0       0.011998     12  2015 2015-12-08
# 940790            0.0       0.011998     12  2015 2015-12-04
# 940791            0.0       0.011998     12  2015 2015-12-03
# 940792            0.0       0.011998     12  2015 2015-12-02
#
#         min_price_(rs./quintal)  max_price_(rs./quintal)  \
# 1050                     3100.0                   3100.0
# 1051                     3100.0                   3100.0
# 1054                     3100.0                   3100.0
# 1055                     3100.0                   3100.0
# 1056                     3100.0                   3100.0
# ...                         ...                      ...
# 940788                   6000.0                   6400.0
# 940789                   6000.0                   6400.0
# 940790                   6000.0                   6400.0
# 940791                   6100.0                   6600.0
# 940792                   6000.0                   6600.0
#
#         modal_price_(rs./quintal)
# 1050                       3100.0
# 1051                       3100.0
# 1054                       3100.0
# 1055                       3100.0
# 1056                       3100.0
# ...                           ...
# 940788                     6200.0
# 940789                     6200.0
# 940790                     6200.0
# 940791                     6400.0
# 940792                     6300.0
#
# [870087 rows x 11 columns]

# %% [markdown]
# ### Saving the encoded dataframe of bengal_gram_whole

# %%
df_encoded.to_csv('bengal_gram_wholeencdf.csv')
